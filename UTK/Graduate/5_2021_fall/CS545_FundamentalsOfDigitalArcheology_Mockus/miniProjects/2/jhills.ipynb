# %%
# !pip install pymongo #NOTE: This command installs pymongo in jupyter environment. It's commented out to not install every run.11
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu") # I added ':7824' port to the end b/c of timeout error to da1
db = client ['fdac21']
coll = db ['MP2']

# dataset fields collected
title = ['Steam Game Data', 
         "Steam Games Dataset : Player count history, Price history and data about games",
         "Steam games complete dataset: 40k steam games dataset", 
         "Steam Games Genres: Genre values for each Steam game by ID", 
         "Over 13,000 Steam Games: Title, release date, price of video games from Steam", 
         "PC Games 2020: Scrape of Steam games supplemented with RAWG API data", 
         "Steam Video Games: Recommend video games from 200k steam user interactions.", 
         "Steam Game Reviews: Reviews for almost 200 top Steam games", 
         "Popularity of games on Steam: 700+ games popularity since the game was released on Steam",
         "Steam Game Reviews: Game reviews scraped from steam API.", 
         "80000 Steam Games DataSet: Dataset containing almost all scrapable information about Games from Steam", 
         "Steam In-Game Players: Daily number of users/in-game players on the Steam platform", 
         "Steam Video Game and Bundle Data", 
         "Condensing Steam: Distilling the Diversity of Gamer Behavior", 
         "Game tags and price of Steam New & Trending 2021: Top games on Steam New and Trending in January", 
         "Data for: Improving video game project scope decisions with data: An analysis of achievements and game completion rates", 
         "Gaming Genres: Using Crowd-Sourced Tags to Explore Family Resemblances in Steam Games.", 
         "Steam Game Review Dataset: Predict whether the reviewer recommend a game", 
         "Steam Video Games: Recommend video games from 200k steam user interactions.", 
         "Steam game review dataset: A dataset for steam game reviews"];

license = ['MIT', 
           "CC BY 4.0", 
           "CC0 1.0 Universal Public Domain Dedication", 
           "N/A", 
           "N/A", 
           "CC0 1.0 Universal Public Domain Dedication", 
           "Database Contents License (DbCL) v1.0", 
           "CC0 1.0 Universal Public Domain Dedication", 
           "CC0 1.0 Universal Public Domain Dedication", 
           "N/A", 
           "Attribution-NonCommercial-ShareAlike 4.0 (CC BY-NC-SA 4.0)", 
           "N/A", 
           "N/A", 
           "No license specified, the work may be protected by copyright.", 
           "N/A", 
           "Attribution-NonCommercial 3.0 (CC BY-NC 3.0)", 
           "N/A", 
           "CC0 1.0 Universal Public Domain Dedication", 
           "http://opendatacommons.org/licenses/dbcl/1.0/",
           "N/A"];

description = ["Originally inspired by steamdb.info, this is a combination of data from publicly available Steam API's and steamspy.com.", 
               "This dataset consists of player count history, price history, and data about 2000 applications available in the Steam games platform.", 
               "This dataset contains more than 40k games from steam shop with detailed data.", 
               "Inside the dataset, you will find genre values for each Steam app ID's. One ID can have multiple values of different genre, i.e. [Action, MOBA].", 
               "13,000 steam games with data including game title, release date, and current price.", 
               "The projects goal is to use this dataset to predict the level of success game developers should expect given their game design details. Features such as 'Indie' (developed by indie studio), 'Soundtrack' (whether or not the game was noted for its soundtrack), and 'Genres', will be able to predict the popularity of the game.", 
               "From over 6,000 games, this dataset is a list of user behaviors, with columns: user-id, game-title, behavior-name, value. The behaviors included are 'purchase' and 'play'. The value indicates the degree to which the behavior was performed - in the case of 'purchase' the value is always 1, and in the case of 'play' the value represents the number of hours the user has played the game.", 
               "I built a video game recommender for my final project and used Steam game reviews. I thought I'd share the files containing the reviews with anyone else interested.", 
               "The data includes information on approximately 500 games on Steam, and the time of the collected data depends on the time of the game's release on Steam. One line represents data (such as average, peak, and month-to-month difference in average) for one game. So the database has a \"long\" format.", 
               "Game reviews scrapped from Steam API.", 
               "This is a dataset contains whatever information that was scrapable, regarding some 80000 games from the Steam official website. Most of the columns contains valuable information that could give a better insight of the game, but cleaning them is required for most of them. make sure to refer the column descriptors for more information. I have not included all reviews and reviews related time series data for the games in this dataset because, it constantly keeps changing and it can be easily fetched using the steam api.", 
               "This database contains the number of in-game players and the total number of users on the Steam platform between 2004 and August 2020, daily periodicity; however, the data is incomplete in the first years, the most complete period seems to be for the last three years. The source of the data is steamdb.info/app/753/graphs/ accessed on 23 August 2020. I uploaded it as I was in need of an interesting database to run a Time Series model, so it can be useful for this.",
               "These datasets contain reviews from the Steam video game platform, and information about which games were bundled together.", 
               "109 MILLION GAMERS 716 MILLION GAMES 1.1 MILLION YEARS OF PLAYTIME A dataset collected and analyzed for the 2016 ACM Internet Measurement Conference article by Mark O Neill, Justin Wu, Elham Vaziripour, and Daniel Zappala Table and attribute descriptions", 
               "I scraped the Game Name, Tag, Rank in order and Price using Python. The data is for January, and might add more across the months.", 
               "The data set used in the research for the paper titled: Improving video game project scope decisions with data: An analysis of achievements and game completion rates. Product and achievement data for video games sold through Valve Corporation's PC video game platform Steam was compiled, and \"game completion\" achievements were evaluated by hand for a random sample chosen from the video games listed. For the purposes of the research, only video games up through the year 2016 were evaluated. Entries with \"completion rates\" also include relevant data from Sergey Galyonkin's SteamSpy service, and \"xPaw\" and \"Marlamin\"'s SteamDB service.", 
               "Abstract of paper 0946 presented at the Digital Humanities Conference 2019 (DH2019), Utrecht , the Netherlands 9-12 July, 2019.", 
               "A lot of gamers write reviews at the game page and have an option of choosing whether they would recommend this game to others or not. However, determining this sentiment automatically from text can help Steam to automatically tag such reviews extracted from other forums across the internet and can help them better judge the popularity of games.", 
               "This dataset is a list of user behaviors, with columns: user-id, game-title, behavior-name, value. The behaviors included are 'purchase' and 'play'. The value indicates the degree to which the behavior was performed - in the case of 'purchase' the value is always 1, and in the case of 'play' the value represents the number of hours the user has played the game.", 
               "The dataset contains id's of games with their overall review scores and total number of reviews about the game in the steam, and total positive and negative reviews of the game."];

urls = [['https://github.com/CraigKelly/steam-data'], 
        ['https://data.mendeley.com/datasets/ycy3sy3vj2/1'], 
        ['https://www.kaggle.com/trolukovich/steam-games-complete-dataset'], 
        ['https://www.kaggle.com/danieliusv/steam-games-genres'], 
        ['https://www.kaggle.com/kingburrito666/over-13000-steam-games'], 
        ['https://www.kaggle.com/jesneuman/pc-games'], 
        ['https://www.kaggle.com/tamber/steam-video-games/data'], 
        ['https://www.kaggle.com/smeeeow/steam-game-reviews'], 
        ['https://www.kaggle.com/michau96/popularity-of-games-on-steam/version/1'], 
        ['https://www.kaggle.com/whoiskk/steam-game-reviews'], 
        ['https://www.kaggle.com/deepann/80000-steam-games-dataset'], 
        ['https://www.kaggle.com/elenasm/steam-concurrent-players'],
        ['https://cseweb.ucsd.edu/~jmcauley/datasets.html'], 
        ['https://academictorrents.com/details/eba3b48fcdaa9e69a927051f1678251a86a546f3', 'https://steam.internet.byu.edu/'], 
        ['https://www.kaggle.com/chanminyi/game-tags-and-price-of-steam-new-trending-2021'], 
        ['https://data.mendeley.com/datasets/jc37n76wyt/1'], 
        ['https://www.narcis.nl/dataset/RecordID/doi%3A10.34894%2FWAFHAM'],
        ['https://www.kaggle.com/arashnic/game-review-dataset'], 
        ['https://www.kaggle.com/tamber/steam-video-games'], 
        ['https://www.kaggle.com/shreyaskshastry/steam-game-review-dataset']]

# for each dataset, insert into mongo database
for i in range (20):
    coll.insert_one ( 
        { 'owner':'jhills', 'topic':'Steam Games', 
          'title': title[i], 'license': license[i], 
          'description': description[i], 
          'urls': urls[i] 
        } )
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipykernel_270/3673287821.py in <module>
#      97 # for each dataset, insert into mongo database
#      98 for i in range (20):
# ---> 99     coll.insert_one (
#     100         { 'owner':'jhills', 'topic':'Steam Games',
#     101           'title': title[i], 'license': license[i],
#
# ~/notebook/jupyterenv/lib/python3.8/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     703         write_concern = self._write_concern_for(session)
#     704         return InsertOneResult(
# --> 705             self._insert(document,
#     706                          write_concern=write_concern,
#     707                          bypass_doc_val=bypass_document_validation,
#
# ...

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac21']
coll = db ['MP2']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find({'owner':'audris'}):
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('614cd44d6c105aaf0da83fcc'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'owner': 'audris',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
